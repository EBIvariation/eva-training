# %% [markdown]
# ## Getting the evidence for an RS ID
#
# Suppose you have an RS ID (e.g. `rs379920406`) for a variant and you're interested in finding what evidence for that variant is contained in the EVA. Specifically you want to know the allele frequencies and genotypes present in any study containing that variant. This notebook will walk you through how to do that using EVA APIs.
#
# For reference, here is the Swagger documentation for all the APIs we will use:
#
# * [Identifiers API](https://www.ebi.ac.uk/eva/webservices/identifiers/swagger-ui.html)
# * [Contig Alias API](https://www.ebi.ac.uk/eva/webservices/contig-alias/swagger-ui.html)
# * [Variant Info API](https://www.ebi.ac.uk/eva/webservices/rest/swagger-ui.html)

# %%
import requests
from collections import Counter

# %%
# The variant ID in question - you can change this and everything else should still run
rsid = 379920406

# %%
identifiers_url = f'https://www.ebi.ac.uk/eva/webservices/identifiers/v1/clustered-variants/{rsid}/submitted'

response = requests.get(identifiers_url)
submitted_variants = response.json()
variants_with_evidence = [sv for sv in submitted_variants if sv['data']['supportedByEvidence']]

# %% [markdown]
# This API endpoint responds with a list of submitted variants associated with the provided clustered variant ID. We've filtered this response to include only those supported by evidence in the EVA (genotypes and allele frequencies).

# %%
variants_with_evidence[0]
# Out:
# {'accession': 7571130482,
#  'version': 1,
#  'data': {'referenceSequenceAccession': 'GCA_002263795.2',
#   'taxonomyAccession': 9913,
#   'projectAccession': 'PRJEB46861',
#   'contig': 'CM008173.2',
#   'start': 85411136,
#   'referenceAllele': 'C',
#   'alternateAllele': 'T',
#   'clusteredVariantAccession': 379920406,
#   'supportedByEvidence': True,
#   'assemblyMatch': True,
#   'allelesMatch': True,
#   'validated': False,
#   'mapWeight': None,
#   'createdDate': '2021-09-08T13:08:25.551',
#   'remappedFrom': None,
#   'remappedDate': None,
#   'remappingId': None,
#   'backPropagatedVariantAccession': None}}

# %% [markdown]
# The actual genotypes and allele frequencies aren't present in this response, but we can get those from another API endpoint which will return more detailed variant information.
#
# There are some quirks to this process which we're working to improve, but here's how you can do it currently.

# %%
# Get relevant accessions
assembly_accession = variants_with_evidence[0]['data']['referenceSequenceAccession']
taxonomy_id = variants_with_evidence[0]['data']['taxonomyAccession']
contig_accession = variants_with_evidence[0]['data']['contig']

# %%
# Translate the accessions to names - optional if you know the names already
species_list_url = 'https://www.ebi.ac.uk/eva/webservices/rest/v1/meta/species/list'
response = requests.get(species_list_url)
species_list = response.json()['response'][0]['result']
for s in species_list:
    if s['assemblyAccession'] == assembly_accession and s['taxonomyId'] == taxonomy_id:
        assembly_code = s['assemblyCode']
        taxonomy_code = s['taxonomyCode']
        break
        
contig_alias_url = f'https://www.ebi.ac.uk/eva/webservices/contig-alias/v1/chromosomes/genbank/{contig_accession}'
response = requests.get(contig_alias_url)
chromosomes = response.json()['_embedded']['chromosomeEntities']
for c in chromosomes:
    if c['assembly']['insdcAccession'] == assembly_accession:
        chrom = c['enaSequenceName']
        break

# %%
print(f'{assembly_accession}\t=> {assembly_code}')
print(f'{taxonomy_id}\t\t=> {taxonomy_code}')
print(f'{contig_accession}\t=> {chrom}')
# Out:
# GCA_002263795.2	=> arsucd12
# 9913		=> btaurus
# CM008173.2	=> 6

# %%
# Position and reference allele should be the same for all, but the alternate allele may be different,
# so we collect all of them to query
alternate_alleles = {v['data']['alternateAllele'] for v in variants_with_evidence}
pos = variants_with_evidence[0]['data']['start']
ref = variants_with_evidence[0]['data']['referenceAllele']

source_variants = []
for alt in alternate_alleles:
    variant_info_url = f'https://www.ebi.ac.uk/eva/webservices/rest/v2/variants/{chrom}:{pos}:{ref}:{alt}/sources?' \
                       f'species={taxonomy_code}&assembly={assembly_code}'
    response = requests.get(variant_info_url)
    source_variants.extend(response.json()['_embedded']['variantSourceEntryWithSampleNamesList'])

# %% [markdown]
# This API endpoint returns the full submitted variant details stored in the EVA, including sample data. It can be very big which is why we don't include it every time we return a variant!

# %%
source_variants[0]
# Out:
# {'fileId': 'ERZ2968700',
#  'studyId': 'PRJEB46861',
#  'format': 'GT',
#  'cohortStats': {'ALL': {'refAllele': 'C',
#    'altAllele': 'T',
#    'variantType': 'SNV',
#    'refAlleleCount': 0,
#    'altAlleleCount': 0,
#    'missingAlleles': 832,
#    'missingGenotypes': 416,
#    'refAlleleFreq': 0.0,
#    'altAlleleFreq': 0.0,
#    'maf': 0.1521739,
#    'mgf': 0.0,
#    'mafAllele': 'T',
#    'mgfGenotype': '1/1',
#    'numSamples': 0,
#    'transition': True,
#    'transversion': False}},
#  'attributes': {'CSQ': 'T|5_prime_UTR_variant|MODIFIER|CSN1S1|ENSBTAG00000007695|Transcript|ENSBTAT00000010119|protein_coding|1/19||ENSBTAT00000010119.3:c.-682C>T||19|||||rs379920406||1||SNV|VGNC||YES|||P5||ENSBTAP00000010119|P02662||UPI0000126FC7||||||||||||||||||||||||||||||||,T|5_prime_UTR_variant|MODIFIER|CSN1S1|ENSBTAG00000007695|Transcript|ENSBTAT00000073072|protein_coding|1/17||ENSBTAT00000073072.1:c.-682C>T||19|||||rs379920406||1||SNV|VGNC|||||A2||ENSBTAP00000069331|||UPI000383DA63||||||||||||||||||||||||||||||||,T|5_prime_UTR_variant|MODIFIER|CSN1S1|ENSBTAG00000007695|Transcript|ENSBTAT00000084279|protein_coding|1/18||ENSBTAT00000084279.1:c.-682C>T||19|||||rs379920406||1||SNV|VGNC|||||P5||ENSBTAP00000071217|||UPI0000126FC7||||||||||||||||||||||||||||||||,T|5_prime_UTR_variant|MODIFIER|CSN1S1|ENSBTAG00000007695|Transcript|ENSBTAT00000084833|protein_coding|1/17||ENSBTAT00000084833.1:c.-682C>T||19|||||rs379920406||1||SNV|VGNC|||||||ENSBTAP00000070805|||UPI000383BD34||||||||||||||||||||||||||||||||',
#   'QUAL': '40.0',
#   'FILTER': 'PASS',
#   'src': '6\t85411136\tAffx-1243368944\tC\tT\t40\tPASS\tCSQ=T|5_prime_UTR_variant|MODIFIER|CSN1S1|ENSBTAG00000007695|Transcript|ENSBTAT00000010119|protein_coding|1/19||ENSBTAT00000010119.3:c.-682C>T||19|||||rs379920406||1||SNV|VGNC||YES|||P5||ENSBTAP00000010119|P02662||UPI0000126FC7||||||||||||||||||||||||||||||||,T|5_prime_UTR_variant|MODIFIER|CSN1S1|ENSBTAG00000007695|Transcript|ENSBTAT00000073072|protein_coding|1/17||ENSBTAT00000073072.1:c.-682C>T||19|||||rs379920406||1||SNV|VGNC|||||A2||ENSBTAP00000069331|||UPI000383DA63||||||||||||||||||||||||||||||||,T|5_prime_UTR_variant|MODIFIER|CSN1S1|ENSBTAG00000007695|Transcript|ENSBTAT00000084279|protein_coding|1/18||ENSBTAT00000084279.1:c.-682C>T||19|||||rs379920406||1||SNV|VGNC|||||P5||ENSBTAP00000071217|||UPI0000126FC7||||||||||||||||||||||||||||||||,T|5_prime_UTR_variant|MODIFIER|CSN1S1|ENSBTAG00000007695|Transcript|ENSBTAT00000084833|protein_coding|1/17||ENSBTAT00000084833.1:c.-682C>T||19|||||rs379920406||1||SNV|VGNC|||||||ENSBTAP00000070805|||UPI000383BD34||||||||||||||||||||||||||||||||'},
#  'samplesData': {'Pinzgauer_0': {'GT': '0/1'},
#   'Pinzgauer_1': {'GT': '0/1'},
#   'Pinzgauer_2': {'GT': '0/1'},
#   'Pinzgauer_3': {'GT': '0/0'},
#   'Pinzgauer_4': {'GT': '0/0'},
#   'Pinzgauer_5': {'GT': '0/1'},
#   'Pinzgauer_6': {'GT': '0/0'},
#   'Pinzgauer_7': {'GT': '0/0'},
#   'Pinzgauer_8': {'GT': '-1/-1'},
#   'Pinzgauer_9': {'GT': '0/1'},
#   'Pinzgauer_10': {'GT': '0/1'},
#   'Pinzgauer_11': {'GT': '0/0'},
#   'Pinzgauer_12': {'GT': '0/0'},
#   'Pinzgauer_13': {'GT': '0/0'},
#   'Pinzgauer_14': {'GT': '0/1'},
#   'Pinzgauer_15': {'GT': '0/1'},
#   'Pinzgauer_16': {'GT': '0/0'},
#   'Pinzgauer_17': {'GT': '0/0'},
#   'Pinzgauer_18': {'GT': '0/0'},
#   'Pinzgauer_19': {'GT': '0/1'},
#   'Pinzgauer_20': {'GT': '0/0'},
#   'Pinzgauer_21': {'GT': '0/0'},
#   'Pinzgauer_22': {'GT': '0/1'},
#   'Holstein_0': {'GT': '-1/-1'},
#   'Holstein_1': {'GT': '-1/-1'},
#   'Holstein_2': {'GT': '-1/-1'},
#   'Holstein_3': {'GT': '-1/-1'},
#   'Holstein_4': {'GT': '-1/-1'},
#   'Holstein_5': {'GT': '-1/-1'},
#   'Holstein_6': {'GT': '-1/-1'},
#   'Holstein_7': {'GT': '-1/-1'},
#   'Holstein_8': {'GT': '-1/-1'},
#   'Holstein_9': {'GT': '-1/-1'},
#   'Holstein_10': {'GT': '-1/-1'},
#   'Holstein_11': {'GT': '-1/-1'},
#   'Holstein_12': {'GT': '-1/-1'},
#   'Holstein_13': {'GT': '-1/-1'},
#   'Holstein_14': {'GT': '-1/-1'},
#   'Holstein_15': {'GT': '-1/-1'},
#   'Holstein_16': {'GT': '-1/-1'},
#   'Holstein_17': {'GT': '-1/-1'},
#   'Holstein_18': {'GT': '-1/-1'},
#   'Holstein_19': {'GT': '-1/-1'},
#   'RotesHoehenvieh_0': {'GT': '-1/-1'},
#   'RotesHoehenvieh_1': {'GT': '-1/-1'},
#   'RotesHoehenvieh_2': {'GT': '-1/-1'},
#   'RotesHoehenvieh_3': {'GT': '-1/-1'},
#   'RotesHoehenvieh_4': {'GT': '-1/-1'},
#   'RotesHoehenvieh_5': {'GT': '-1/-1'},
#   'RotesHoehenvieh_6': {'GT': '-1/-1'},
#   'RotesHoehenvieh_7': {'GT': '-1/-1'},
#   'RotesHoehenvieh_8': {'GT': '-1/-1'},
#   'RotesHoehenvieh_9': {'GT': '-1/-1'},
#   'RotesHoehenvieh_10': {'GT': '-1/-1'},
#   'RotesHoehenvieh_11': {'GT': '-1/-1'},
#   'RotesHoehenvieh_12': {'GT': '-1/-1'},
#   'RotesHoehenvieh_13': {'GT': '-1/-1'},
#   'RotesHoehenvieh_14': {'GT': '-1/-1'},
#   'RotesHoehenvieh_15': {'GT': '-1/-1'},
#   'RotesHoehenvieh_16': {'GT': '-1/-1'},
#   'RotesHoehenvieh_17': {'GT': '-1/-1'},
#   'RotesHoehenvieh_18': {'GT': '-1/-1'},
#   'RotesHoehenvieh_19': {'GT': '-1/-1'},
#   'RotesHoehenvieh_20': {'GT': '-1/-1'},
#   'RotesHoehenvieh_21': {'GT': '-1/-1'},
#   'RotesHoehenvieh_22': {'GT': '-1/-1'},
#   'RotesHoehenvieh_23': {'GT': '-1/-1'},
#   'RotesHoehenvieh_24': {'GT': '-1/-1'},
#   'RotesHoehenvieh_25': {'GT': '-1/-1'},
#   'RotesHoehenvieh_26': {'GT': '-1/-1'},
#   'RotesHoehenvieh_27': {'GT': '-1/-1'},
#   'RotesHoehenvieh_28': {'GT': '-1/-1'},
#   'RotesHoehenvieh_29': {'GT': '-1/-1'},
#   'Hinterwaelder_0': {'GT': '0/0'},
#   'Hinterwaelder_1': {'GT': '0/0'},
#   'Gelbvieh_0': {'GT': '0/0'},
#   'Gelbvieh_1': {'GT': '0/1'},
#   'Gelbvieh_2': {'GT': '0/0'},
#   'Gelbvieh_3': {'GT': '0/0'},
#   'Gelbvieh_4': {'GT': '0/1'},
#   'Gelbvieh_5': {'GT': '0/0'},
#   'Gelbvieh_6': {'GT': '0/0'},
#   'Gelbvieh_7': {'GT': '0/0'},
#   'Gelbvieh_8': {'GT': '0/0'},
#   'Gelbvieh_9': {'GT': '0/0'},
#   'DNRotbunt_0': {'GT': '-1/-1'},
#   'DNRotbunt_1': {'GT': '-1/-1'},
#   'DNRotbunt_2': {'GT': '-1/-1'},
#   'DNRotbunt_3': {'GT': '-1/-1'},
#   'DNRotbunt_4': {'GT': '-1/-1'},
#   'DNRotbunt_5': {'GT': '-1/-1'},
#   'DNRotbunt_6': {'GT': '-1/-1'},
#   'DNRotbunt_7': {'GT': '-1/-1'},
#   'DNRotbunt_8': {'GT': '-1/-1'},
#   'DNRotbunt_9': {'GT': '-1/-1'},
#   'DNRotbunt_10': {'GT': '-1/-1'},
#   'DNRotbunt_11': {'GT': '-1/-1'},
#   'DNRotbunt_12': {'GT': '-1/-1'},
#   'DNRotbunt_13': {'GT': '-1/-1'},
#   'DNRotbunt_14': {'GT': '-1/-1'},
#   'DNRotbunt_15': {'GT': '-1/-1'},
#   'DNRotbunt_16': {'GT': '-1/-1'},
#   'DNRotbunt_17': {'GT': '-1/-1'},
#   'DNRotbunt_18': {'GT': '-1/-1'},
#   'DNRotbunt_19': {'GT': '-1/-1'},
#   'DNRotbunt_20': {'GT': '-1/-1'},
#   'DNRotbunt_21': {'GT': '-1/-1'},
#   'DNRotbunt_22': {'GT': '-1/-1'},
#   'DNRotbunt_23': {'GT': '-1/-1'},
#   'DNRotbunt_24': {'GT': '-1/-1'},
#   'DNRotbunt_25': {'GT': '-1/-1'},
#   'DNRotbunt_26': {'GT': '-1/-1'},
#   'DNRotbunt_27': {'GT': '-1/-1'},
#   'DNRotbunt_28': {'GT': '-1/-1'},
#   'DNRotbunt_29': {'GT': '-1/-1'},
#   'DSN_0': {'GT': '-1/-1'},
#   'DSN_1': {'GT': '-1/-1'},
#   'DSN_2': {'GT': '-1/-1'},
#   'DSN_3': {'GT': '-1/-1'},
#   'DSN_4': {'GT': '-1/-1'},
#   'DSN_5': {'GT': '-1/-1'},
#   'DSN_6': {'GT': '-1/-1'},
#   'DSN_7': {'GT': '-1/-1'},
#   'DSN_8': {'GT': '-1/-1'},
#   'DSN_9': {'GT': '-1/-1'},
#   'DSN_10': {'GT': '-1/-1'},
#   'DSN_11': {'GT': '-1/-1'},
#   'DSN_12': {'GT': '-1/-1'},
#   'DSN_13': {'GT': '-1/-1'},
#   'DSN_14': {'GT': '-1/-1'},
#   'DSN_15': {'GT': '-1/-1'},
#   'DSN_16': {'GT': '-1/-1'},
#   'DSN_17': {'GT': '-1/-1'},
#   'DSN_18': {'GT': '-1/-1'},
#   'DSN_19': {'GT': '-1/-1'},
#   'DSN_20': {'GT': '-1/-1'},
#   'DSN_21': {'GT': '-1/-1'},
#   'DSN_22': {'GT': '-1/-1'},
#   'DSN_23': {'GT': '-1/-1'},
#   'DSN_24': {'GT': '-1/-1'},
#   'DSN_25': {'GT': '-1/-1'},
#   'DSN_26': {'GT': '-1/-1'},
#   'DSN_27': {'GT': '-1/-1'},
#   'DSN_28': {'GT': '-1/-1'},
#   'DSN_29': {'GT': '-1/-1'},
#   'DSN_30': {'GT': '-1/-1'},
#   'DSN_31': {'GT': '-1/-1'},
#   'DSN_32': {'GT': '-1/-1'},
#   'DSN_33': {'GT': '-1/-1'},
#   'DSN_34': {'GT': '-1/-1'},
#   'DSN_35': {'GT': '-1/-1'},
#   'DSN_36': {'GT': '-1/-1'},
#   'DSN_37': {'GT': '-1/-1'},
#   'DSN_38': {'GT': '-1/-1'},
#   'DSN_39': {'GT': '-1/-1'},
#   'DSN_40': {'GT': '-1/-1'},
#   'DSN_41': {'GT': '-1/-1'},
#   'DSN_42': {'GT': '-1/-1'},
#   'DSN_43': {'GT': '-1/-1'},
#   'DSN_44': {'GT': '-1/-1'},
#   'DSN_45': {'GT': '-1/-1'},
#   'DSN_46': {'GT': '-1/-1'},
#   'DSN_47': {'GT': '-1/-1'},
#   'DSN_48': {'GT': '-1/-1'},
#   'DSN_49': {'GT': '-1/-1'},
#   'DSN_50': {'GT': '-1/-1'},
#   'DSN_51': {'GT': '-1/-1'},
#   'DSN_52': {'GT': '-1/-1'},
#   'DSN_53': {'GT': '-1/-1'},
#   'DSN_54': {'GT': '-1/-1'},
#   'DSN_55': {'GT': '-1/-1'},
#   'DSN_56': {'GT': '-1/-1'},
#   'DSN_57': {'GT': '-1/-1'},
#   'DSN_58': {'GT': '-1/-1'},
#   'DSN_59': {'GT': '-1/-1'},
#   'DSN_60': {'GT': '-1/-1'},
#   'DSN_61': {'GT': '-1/-1'},
#   'DSN_62': {'GT': '-1/-1'},
#   'DSN_63': {'GT': '-1/-1'},
#   'DSN_64': {'GT': '-1/-1'},
#   'DSN_65': {'GT': '-1/-1'},
#   'DSN_66': {'GT': '-1/-1'},
#   'DSN_67': {'GT': '-1/-1'},
#   'DSN_68': {'GT': '-1/-1'},
#   'DSN_69': {'GT': '-1/-1'},
#   'DSN_70': {'GT': '-1/-1'},
#   'DSN_71': {'GT': '-1/-1'},
#   'DSN_72': {'GT': '-1/-1'},
#   'DSN_73': {'GT': '-1/-1'},
#   'DSN_74': {'GT': '-1/-1'},
#   'DSN_75': {'GT': '-1/-1'},
#   'DSN_76': {'GT': '-1/-1'},
#   'DSN_77': {'GT': '-1/-1'},
#   'DSN_78': {'GT': '-1/-1'},
#   'DSN_79': {'GT': '-1/-1'},
#   'DSN_80': {'GT': '-1/-1'},
#   'DSN_81': {'GT': '-1/-1'},
#   'DSN_82': {'GT': '-1/-1'},
#   'DSN_83': {'GT': '-1/-1'},
#   'DSN_84': {'GT': '-1/-1'},
#   'DSN_85': {'GT': '-1/-1'},
#   'DSN_86': {'GT': '-1/-1'},
#   'DSN_87': {'GT': '-1/-1'},
#   'DSN_88': {'GT': '-1/-1'},
#   'DSN_89': {'GT': '-1/-1'},
#   'DSN_90': {'GT': '-1/-1'},
#   'DSN_91': {'GT': '-1/-1'},
#   'DSN_92': {'GT': '-1/-1'},
#   'DSN_93': {'GT': '-1/-1'},
#   'DSN_94': {'GT': '-1/-1'},
#   'DSN_95': {'GT': '-1/-1'},
#   'DSN_96': {'GT': '-1/-1'},
#   'DSN_97': {'GT': '-1/-1'},
#   'DSN_98': {'GT': '-1/-1'},
#   'DSN_99': {'GT': '-1/-1'},
#   'DSN_100': {'GT': '-1/-1'},
#   'DSN_101': {'GT': '-1/-1'},
#   'DSN_102': {'GT': '-1/-1'},
#   'DSN_103': {'GT': '-1/-1'},
#   'DSN_104': {'GT': '-1/-1'},
#   'DSN_105': {'GT': '-1/-1'},
#   'DSN_106': {'GT': '-1/-1'},
#   'DSN_107': {'GT': '-1/-1'},
#   'DSN_108': {'GT': '-1/-1'},
#   'DSN_109': {'GT': '-1/-1'},
#   'DSN_110': {'GT': '-1/-1'},
#   'DSN_111': {'GT': '-1/-1'},
#   'DSN_112': {'GT': '-1/-1'},
#   'DSN_113': {'GT': '-1/-1'},
#   'DSN_114': {'GT': '-1/-1'},
#   'DSN_115': {'GT': '-1/-1'},
#   'DSN_116': {'GT': '-1/-1'},
#   'DSN_117': {'GT': '-1/-1'},
#   'DSN_118': {'GT': '-1/-1'},
#   'DSN_119': {'GT': '-1/-1'},
#   'DSN_120': {'GT': '-1/-1'},
#   'DSN_121': {'GT': '-1/-1'},
#   'DSN_122': {'GT': '-1/-1'},
#   'DSN_123': {'GT': '-1/-1'},
#   'DSN_124': {'GT': '-1/-1'},
#   'DSN_125': {'GT': '-1/-1'},
#   'DSN_126': {'GT': '-1/-1'},
#   'DSN_127': {'GT': '-1/-1'},
#   'DSN_128': {'GT': '-1/-1'},
#   'DSN_129': {'GT': '-1/-1'},
#   'DSN_130': {'GT': '-1/-1'},
#   'DSN_131': {'GT': '-1/-1'},
#   'DSN_132': {'GT': '-1/-1'},
#   'DSN_133': {'GT': '-1/-1'},
#   'DSN_134': {'GT': '-1/-1'},
#   'DSN_135': {'GT': '-1/-1'},
#   'DSN_136': {'GT': '-1/-1'},
#   'DSN_137': {'GT': '-1/-1'},
#   'DSN_138': {'GT': '-1/-1'},
#   'DSN_139': {'GT': '-1/-1'},
#   'DSN_140': {'GT': '-1/-1'},
#   'DSN_141': {'GT': '-1/-1'},
#   'DSN_142': {'GT': '-1/-1'},
#   'DSN_143': {'GT': '-1/-1'},
#   'DSN_144': {'GT': '-1/-1'},
#   'DSN_145': {'GT': '-1/-1'},
#   'DSN_146': {'GT': '-1/-1'},
#   'DSN_147': {'GT': '-1/-1'},
#   'DSN_148': {'GT': '-1/-1'},
#   'DSN_149': {'GT': '-1/-1'},
#   'DSN_150': {'GT': '-1/-1'},
#   'DSN_151': {'GT': '-1/-1'},
#   'DSN_152': {'GT': '-1/-1'},
#   'DSN_153': {'GT': '-1/-1'},
#   'DSN_154': {'GT': '-1/-1'},
#   'DSN_155': {'GT': '-1/-1'},
#   'DSN_156': {'GT': '-1/-1'},
#   'DSN_157': {'GT': '-1/-1'},
#   'DSN_158': {'GT': '-1/-1'},
#   'DSN_159': {'GT': '-1/-1'},
#   'DSN_160': {'GT': '-1/-1'},
#   'DSN_161': {'GT': '-1/-1'},
#   'DSN_162': {'GT': '-1/-1'},
#   'DSN_163': {'GT': '-1/-1'},
#   'DSN_164': {'GT': '-1/-1'},
#   'DSN_165': {'GT': '-1/-1'},
#   'DSN_166': {'GT': '-1/-1'},
#   'DSN_167': {'GT': '-1/-1'},
#   'DSN_168': {'GT': '-1/-1'},
#   'DSN_169': {'GT': '-1/-1'},
#   'DSN_170': {'GT': '-1/-1'},
#   'DSN_171': {'GT': '-1/-1'},
#   'DSN_172': {'GT': '-1/-1'},
#   'DSN_173': {'GT': '-1/-1'},
#   'DSN_174': {'GT': '-1/-1'},
#   'DSN_175': {'GT': '-1/-1'},
#   'DSN_176': {'GT': '-1/-1'},
#   'DSN_177': {'GT': '-1/-1'},
#   'DSN_178': {'GT': '-1/-1'},
#   'DSN_179': {'GT': '-1/-1'},
#   'DSN_180': {'GT': '-1/-1'},
#   'DSN_181': {'GT': '-1/-1'},
#   'DSN_182': {'GT': '-1/-1'},
#   'DSN_183': {'GT': '-1/-1'},
#   'DSN_184': {'GT': '-1/-1'},
#   'DSN_185': {'GT': '-1/-1'},
#   'DSN_186': {'GT': '-1/-1'},
#   'DSN_187': {'GT': '-1/-1'},
#   'DSN_188': {'GT': '-1/-1'},
#   'DSN_189': {'GT': '-1/-1'},
#   'DSN_190': {'GT': '-1/-1'},
#   'DSN_191': {'GT': '-1/-1'},
#   'DSN_192': {'GT': '-1/-1'},
#   'DSN_193': {'GT': '-1/-1'},
#   'DSN_194': {'GT': '-1/-1'},
#   'DSN_195': {'GT': '-1/-1'},
#   'DSN_196': {'GT': '-1/-1'},
#   'DSN_197': {'GT': '-1/-1'},
#   'DSN_198': {'GT': '-1/-1'},
#   'DSN_199': {'GT': '-1/-1'},
#   'DSN_200': {'GT': '-1/-1'},
#   'DSN_201': {'GT': '-1/-1'},
#   'DSN_202': {'GT': '-1/-1'},
#   'DSN_203': {'GT': '-1/-1'},
#   'DSN_204': {'GT': '-1/-1'},
#   'DSN_205': {'GT': '-1/-1'},
#   'DSN_206': {'GT': '-1/-1'},
#   'DSN_207': {'GT': '-1/-1'},
#   'DSN_208': {'GT': '-1/-1'},
#   'DSN_209': {'GT': '-1/-1'},
#   'DSN_210': {'GT': '-1/-1'},
#   'DSN_211': {'GT': '-1/-1'},
#   'DSN_212': {'GT': '-1/-1'},
#   'DSN_213': {'GT': '-1/-1'},
#   'DSN_214': {'GT': '-1/-1'},
#   'DSN_215': {'GT': '-1/-1'},
#   'DSN_216': {'GT': '-1/-1'},
#   'DSN_217': {'GT': '-1/-1'},
#   'DSN_218': {'GT': '-1/-1'},
#   'DSN_219': {'GT': '-1/-1'},
#   'DSN_220': {'GT': '-1/-1'},
#   'DSN_221': {'GT': '-1/-1'},
#   'DSN_222': {'GT': '-1/-1'},
#   'DSN_223': {'GT': '-1/-1'},
#   'DSN_224': {'GT': '-1/-1'},
#   'DSN_225': {'GT': '-1/-1'},
#   'DSN_226': {'GT': '-1/-1'},
#   'DSN_227': {'GT': '-1/-1'},
#   'DSN_228': {'GT': '-1/-1'},
#   'DSN_229': {'GT': '-1/-1'},
#   'DSN_230': {'GT': '-1/-1'},
#   'DSN_231': {'GT': '-1/-1'},
#   'DSN_232': {'GT': '-1/-1'},
#   'DSN_233': {'GT': '-1/-1'},
#   'DSN_234': {'GT': '-1/-1'},
#   'DSN_235': {'GT': '-1/-1'},
#   'DSN_236': {'GT': '-1/-1'},
#   'DSN_237': {'GT': '-1/-1'},
#   'DSN_238': {'GT': '-1/-1'},
#   'DSN_239': {'GT': '-1/-1'},
#   'DSN_240': {'GT': '-1/-1'},
#   'DSN_241': {'GT': '-1/-1'},
#   'DSN_242': {'GT': '-1/-1'},
#   'DSN_243': {'GT': '-1/-1'},
#   'DSN_244': {'GT': '-1/-1'},
#   'DSN_245': {'GT': '-1/-1'},
#   'DSN_246': {'GT': '-1/-1'},
#   'DSN_247': {'GT': '-1/-1'},
#   'DSN_248': {'GT': '-1/-1'},
#   'DSN_249': {'GT': '-1/-1'},
#   'DSN_250': {'GT': '-1/-1'},
#   'DSN_251': {'GT': '-1/-1'},
#   'DSN_252': {'GT': '-1/-1'},
#   'DSN_253': {'GT': '-1/-1'},
#   'DSN_254': {'GT': '-1/-1'},
#   'DSN_255': {'GT': '-1/-1'},
#   'DSN_256': {'GT': '-1/-1'},
#   'DSN_257': {'GT': '-1/-1'},
#   'DSN_258': {'GT': '-1/-1'},
#   'DSN_259': {'GT': '-1/-1'},
#   'DSN_260': {'GT': '-1/-1'},
#   'DSN_261': {'GT': '-1/-1'},
#   'DSN_262': {'GT': '-1/-1'},
#   'DSN_263': {'GT': '-1/-1'},
#   'DSN_264': {'GT': '-1/-1'},
#   'DSN_265': {'GT': '-1/-1'},
#   'DSN_266': {'GT': '-1/-1'},
#   'DSN_267': {'GT': '-1/-1'},
#   'DSN_268': {'GT': '-1/-1'},
#   'DSN_269': {'GT': '-1/-1'},
#   'DSN_270': {'GT': '-1/-1'},
#   'DSN_271': {'GT': '-1/-1'},
#   'DSN_272': {'GT': '-1/-1'},
#   'DSN_273': {'GT': '-1/-1'},
#   'DSN_274': {'GT': '-1/-1'},
#   'DSN_275': {'GT': '-1/-1'},
#   'DSN_276': {'GT': '-1/-1'},
#   'DSN_277': {'GT': '-1/-1'},
#   'DSN_278': {'GT': '-1/-1'},
#   'DSN_279': {'GT': '-1/-1'},
#   'DSN_280': {'GT': '-1/-1'},
#   'DSN_281': {'GT': '-1/-1'},
#   'DSN_282': {'GT': '-1/-1'},
#   'DSN_283': {'GT': '-1/-1'},
#   'DSN_284': {'GT': '-1/-1'},
#   'DSN_285': {'GT': '-1/-1'},
#   'DSN_286': {'GT': '-1/-1'},
#   'DSN_287': {'GT': '-1/-1'},
#   'DSN_288': {'GT': '-1/-1'},
#   'DSN_289': {'GT': '-1/-1'},
#   'DSN_290': {'GT': '-1/-1'},
#   'DSN_291': {'GT': '-1/-1'},
#   'DSN_292': {'GT': '-1/-1'},
#   'DSN_293': {'GT': '-1/-1'},
#   'DSN_294': {'GT': '-1/-1'},
#   'DSN_295': {'GT': '-1/-1'},
#   'DSN_296': {'GT': '-1/-1'},
#   'DSN_297': {'GT': '-1/-1'},
#   'DSN_298': {'GT': '-1/-1'},
#   'DSN_299': {'GT': '-1/-1'},
#   'Angler_0': {'GT': '-1/-1'},
#   'Angler_1': {'GT': '-1/-1'},
#   'Angler_2': {'GT': '-1/-1'},
#   'Angler_3': {'GT': '-1/-1'},
#   'Angler_4': {'GT': '-1/-1'},
#   'Angler_5': {'GT': '-1/-1'},
#   'Angler_6': {'GT': '-1/-1'},
#   'Angler_7': {'GT': '-1/-1'},
#   'Angler_8': {'GT': '-1/-1'},
#   'Angler_9': {'GT': '-1/-1'},
#   'Angler_10': {'GT': '-1/-1'},
#   'Angler_11': {'GT': '-1/-1'},
#   'Angler_12': {'GT': '-1/-1'},
#   'Angler_13': {'GT': '-1/-1'},
#   'Angler_14': {'GT': '-1/-1'},
#   'Angler_15': {'GT': '-1/-1'},
#   'Angler_16': {'GT': '-1/-1'},
#   'Angler_17': {'GT': '-1/-1'},
#   'Angler_18': {'GT': '-1/-1'},
#   'Angler_19': {'GT': '-1/-1'},
#   'Angler_20': {'GT': '-1/-1'},
#   'Angler_21': {'GT': '-1/-1'},
#   'Angler_22': {'GT': '-1/-1'},
#   'Angler_23': {'GT': '-1/-1'},
#   'Angler_24': {'GT': '-1/-1'},
#   'Angler_25': {'GT': '-1/-1'},
#   'Angler_26': {'GT': '-1/-1'},
#   'Angler_27': {'GT': '-1/-1'},
#   'Angler_28': {'GT': '-1/-1'},
#   'Angler_29': {'GT': '-1/-1'},
#   'Butana_0': {'GT': '-1/-1'},
#   'Butana_1': {'GT': '-1/-1'},
#   'Butana_2': {'GT': '-1/-1'},
#   'Butana_3': {'GT': '-1/-1'},
#   'Butana_4': {'GT': '-1/-1'},
#   'OriginalBraunvieh_0': {'GT': '0/1'},
#   'OriginalBraunvieh_1': {'GT': '0/0'},
#   'OriginalBraunvieh_2': {'GT': '0/1'},
#   'OriginalBraunvieh_3': {'GT': '0/0'},
#   'OriginalBraunvieh_4': {'GT': '0/0'},
#   'OriginalBraunvieh_5': {'GT': '0/0'},
#   'OriginalBraunvieh_6': {'GT': '0/0'},
#   'OriginalBraunvieh_7': {'GT': '0/0'},
#   'OriginalBraunvieh_8': {'GT': '0/0'},
#   'OriginalBraunvieh_9': {'GT': '0/0'},
#   'OriginalBraunvieh_10': {'GT': '0/0'},
#   'OriginalBraunvieh_11': {'GT': '0/0'}}}

# %%
# Get the minor allele frequencies
allele_freqs = []
for variant in source_variants:
    if 'cohortStats' in variant:
        allele_freqs.append(variant['cohortStats']['ALL']['maf'])

# %%
allele_freqs
# Out:
# [0.1521739, 0.111]

# %%
# Get all the genotypes present in samples
genotypes = Counter()
for variant in source_variants:
    if 'samplesData' in variant:
        for _, sample in variant['samplesData'].items():
            if 'GT' in sample:
                genotypes[sample['GT']] += 1

# %%
# Note that -1 means the value is missing
for gt, count in genotypes.items():
    print(f'{gt}: {count}')
# Out:
# 0/1: 14
# 0/0: 32
# -1/-1: 416
